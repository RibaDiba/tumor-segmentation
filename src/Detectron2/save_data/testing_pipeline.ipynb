# %%
# imports 

import argparse, os
from get_data import get_files 
from visualize_images import create_images

from enum import Enum, auto
import os, cv2
from detectron2.config import get_cfg
from detectron2.engine import DefaultPredictor
from detectron2 import model_zoo
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog
from detectron2.utils.visualizer import ColorMode
from collections import defaultdict

from visualize_images import return_cfg, ImageType, return_predictor, create_paths, visualize_image

# %%
# get file names, cfg, and predictor 
names_dict = get_files()
rgb_cfg = return_cfg(model_type=ImageType.RGB)
rgb_predictor = return_predictor(rgb_cfg)

# %%
split_key = next(iter(names_dict))
basename = next(iter(names_dict[split_key]))
image_type = next(iter(names_dict[split_key][basename]))

paths = create_paths('./testing-notebook-10', names_dict)
base_path = paths[basename]

# %%
print(basename)
# Out:
# train_130.jpg

# %%
visualize_image(
    im_dir=names_dict[split_key][basename][image_type],
    predictor=rgb_predictor, 
    cfg=rgb_cfg,
    output_path=base_path,
    name=basename,
    type=image_type
)
# Out:
# Processesing: ../../../data/processed_data/rgb/train/images/train_130.jpg
# /home/am0532/.conda/envs/tumor-env/lib/python3.12/site-packages/torch/functional.py:554: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4314.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
